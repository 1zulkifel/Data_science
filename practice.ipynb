# %%
import numpy as np
a=np.random.random((64,3,32,10,))
b=np.random.random((32,10))
c=np.maximum(a,b)
c
# Out:
# array([[[[0.84743209, 0.65053768, 0.9710684 , ..., 0.39044513,
#           0.72565498, 0.83319689],
#          [0.74214328, 0.72364319, 0.19944986, ..., 0.9121608 ,
#           0.56836244, 0.74808607],
#          [0.78664334, 0.33552541, 0.12789903, ..., 0.72516773,
#           0.88627418, 0.31318738],
#          ...,
#          [0.76726265, 0.64642396, 0.85385678, ..., 0.51231482,
#           0.67685664, 0.65237783],
#          [0.99305602, 0.53565454, 0.65920562, ..., 0.81751973,
#           0.67974752, 0.9090785 ],
#          [0.61429071, 0.2935632 , 0.64095017, ..., 0.95934283,
#           0.66193003, 0.78167535]],
#
#         [[0.37461975, 0.76696044, 0.9710684 , ..., 0.77640881,
#           0.72565498, 0.43150121],
#          [0.41950135, 0.72364319, 0.77466652, ..., 0.91727462,
#           0.74832412, 0.74808607],
#          [0.78664334, 0.71483249, 0.11582313, ..., 0.26133638,
#           0.85612362, 0.66948966],
#          ...,
# ...
